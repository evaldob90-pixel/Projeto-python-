# %%
# ============================================================
#   SISTEMA DE MONITORAMENTO DO NÍVEL DO RIO NEGRO
#   Projeto: Curso de IA - CETAM | Módulo Python
# ============================================================

# --- FAIXAS DE REFERÊNCIA (em metros) ---
NIVEL_CHEIA      = 29.00   # Acima disso → CHEIA
NIVEL_SECA       = 18.00   # Abaixo disso → SECA
ALERTA_CHEIA     = 29.97   # Recorde histórico de cheia (2021/2022)
ALERTA_SECA      = 13.64   # Recorde histórico de seca

MESES = [
    "Janeiro", "Fevereiro", "Março",    "Abril",
    "Maio",    "Junho",     "Julho",    "Agosto",
    "Setembro","Outubro",   "Novembro", "Dezembro"
]


# ============================================================
# FUNÇÕES AUXILIARES
# ============================================================

def classificar_nivel(nivel: float) -> str:
    """Classifica o nível do rio em CHEIA, NORMAL ou SECA."""
    if nivel > NIVEL_CHEIA:
        return "CHEIA"
    elif nivel < NIVEL_SECA:
        return "SECA"
    else:
        return "NORMAL"


def verificar_alerta(nivel: float) -> str | None:
    """Retorna mensagem de alerta se ultrapassar limites históricos."""
    if nivel > ALERTA_CHEIA:
        return (f"⚠️  ALERTA CRÍTICO! Nível {nivel:.2f}m SUPERA o recorde "
                f"histórico de CHEIA ({ALERTA_CHEIA}m - 2021/2022)!")
    elif nivel < ALERTA_SECA:
        return (f"⚠️  ALERTA CRÍTICO! Nível {nivel:.2f}m está ABAIXO do recorde "
                f"histórico de SECA ({ALERTA_SECA}m)!")
    return None


def ler_nivel(prompt: str) -> float:
    """Lê e valida um nível do rio informado pelo usuário."""
    while True:
        try:
            valor = float(input(prompt))
            if valor < 0 or valor > 60:
                print("  ❌  Valor fora do intervalo realista (0 a 60 m). Tente novamente.")
                continue
            return valor
        except ValueError:
            print("  ❌  Entrada inválida. Digite um número (ex: 25.40).")


def coletar_dados_usuario(mes: str, num_dias: int) -> list[float]:
    """Coleta leituras diárias digitadas pelo usuário."""
    print(f"\n  Informe os níveis diários para {mes} ({num_dias} dias):")
    leituras = []
    for dia in range(1, num_dias + 1):
        nivel = ler_nivel(f"    Dia {dia:02d}: ")
        leituras.append(nivel)
    return leituras


def usar_dados_simulados(mes: str) -> list[float]:
    """Retorna dados fictícios pré-definidos para demonstração."""
    import random
    random.seed(42)
    # Simula oscilação realista baseada no comportamento do Rio Negro
    base = {
        "Janeiro": 25.0, "Fevereiro": 27.5, "Março": 29.5, "Abril": 30.2,
        "Maio": 29.8, "Junho": 28.0, "Julho": 25.5, "Agosto": 22.0,
        "Setembro": 18.5, "Outubro": 17.0, "Novembro": 18.5, "Dezembro": 22.0
    }
    nivel_base = base.get(mes, 24.0)
    leituras = []
    nivel_atual = nivel_base
    for _ in range(30):
        variacao = random.uniform(-0.6, 0.6)
        nivel_atual = round(nivel_atual + variacao, 2)
        nivel_atual = max(10.0, min(35.0, nivel_atual))
        leituras.append(nivel_atual)
    return leituras


# ============================================================
# ANÁLISE MENSAL
# ============================================================

def analisar_mes(mes: str, leituras: list[float]) -> dict:
    """Processa todas as leituras de um mês e retorna o relatório."""
    resultados_dias = []
    alertas = []

    for dia, nivel in enumerate(leituras, start=1):
        classificacao = classificar_nivel(nivel)
        alerta = verificar_alerta(nivel)
        resultados_dias.append({
            "dia": dia,
            "nivel": nivel,
            "classificacao": classificacao,
        })
        if alerta:
            alertas.append(f"    Dia {dia:02d}: {alerta}")

    # Média mensal
    media = sum(leituras) / len(leituras)

    # Dia de maior variação (diferença entre dias consecutivos)
    maior_variacao = 0.0
    dia_maior_variacao = 1
    for i in range(1, len(leituras)):
        variacao = abs(leituras[i] - leituras[i - 1])
        if variacao > maior_variacao:
            maior_variacao = variacao
            dia_maior_variacao = i + 1  # dia atual (base 1)

    # Contagem por classificação
    contagem = {"CHEIA": 0, "NORMAL": 0, "SECA": 0}
    for r in resultados_dias:
        contagem[r["classificacao"]] += 1

    return {
        "mes": mes,
        "leituras": leituras,
        "resultados_dias": resultados_dias,
        "media": media,
        "maior_variacao": maior_variacao,
        "dia_maior_variacao": dia_maior_variacao,
        "contagem": contagem,
        "alertas": alertas,
    }


# ============================================================
# EXIBIÇÃO DE RESULTADOS
# ============================================================

ICONE = {"CHEIA": "🌊", "NORMAL": "✅", "SECA": "🏜️ "}

def exibir_relatorio(rel: dict) -> None:
    """Imprime o relatório completo do mês."""
    sep = "=" * 60
    print(f"\n{sep}")
    print(f"  RELATÓRIO — {rel['mes'].upper()}")
    print(sep)

    # Leituras diárias
    print("\n  📅 LEITURAS DIÁRIAS:")
    for r in rel["resultados_dias"]:
        icone = ICONE[r["classificacao"]]
        print(f"    Dia {r['dia']:02d}: {r['nivel']:6.2f} m  → {icone}  {r['classificacao']}")

    # Resumo
    print(f"\n  📊 RESUMO DO MÊS:")
    print(f"    • Média mensal      : {rel['media']:.2f} m  ({classificar_nivel(rel['media'])})")
    print(f"    • Dias em CHEIA     : {rel['contagem']['CHEIA']}")
    print(f"    • Dias NORMAIS      : {rel['contagem']['NORMAL']}")
    print(f"    • Dias em SECA      : {rel['contagem']['SECA']}")
    print(f"    • Maior variação    : {rel['maior_variacao']:.2f} m  (Dia {rel['dia_maior_variacao']:02d})")

    # Alertas históricos
    if rel["alertas"]:
        print(f"\n  🚨 ALERTAS HISTÓRICOS:")
        for a in rel["alertas"]:
            print(a)
    else:
        print(f"\n  ✅ Nenhum nível ultrapassou os limites históricos.")

    print(sep)


def exibir_resumo_anual(relatorios: list[dict]) -> None:
    """Exibe tabela-resumo de todos os meses analisados."""
    if not relatorios:
        return
    print("\n" + "=" * 60)
    print("  RESUMO ANUAL — RIO NEGRO")
    print("=" * 60)
    print(f"  {'Mês':<12} {'Média (m)':>10} {'Classificação':<10} {'Alertas':>7}")
    print("  " + "-" * 46)
    for r in relatorios:
        classe = classificar_nivel(r["media"])
        icone = ICONE[classe]
        qtd_alertas = len(r["alertas"])
        print(f"  {r['mes']:<12} {r['media']:>10.2f} {icone} {classe:<9} {qtd_alertas:>6}")
    print("=" * 60)


# ============================================================
# MENU PRINCIPAL
# ============================================================

def menu_principal() -> None:
    print("\n" + "=" * 60)
    print("   🌊  MONITORAMENTO DO NÍVEL DO RIO NEGRO  🌊")
    print("   Projeto CETAM — Curso de IA | Módulo Python")
    print("=" * 60)
    print("\n  MENU PRINCIPAL")
    print("  1 - Analisar um mês (dados simulados)")
    print("  2 - Analisar um mês (inserir dados manualmente)")
    print("  3 - Gerar relatório anual completo (simulado)")
    print("  0 - Sair")
    print()


def escolher_mes() -> tuple[str, int]:
    """Permite o usuário escolher o mês."""
    print("\n  Escolha o mês:")
    for i, m in enumerate(MESES, 1):
        print(f"    {i:2d}. {m}")
    while True:
        try:
            escolha = int(input("\n  Digite o número do mês: "))
            if 1 <= escolha <= 12:
                mes = MESES[escolha - 1]
                # Dias por mês (simplificado, sem ano bissexto)
                dias_por_mes = [31,28,31,30,31,30,31,31,30,31,30,31]
                return mes, dias_por_mes[escolha - 1]
            else:
                print("  ❌  Número inválido. Escolha entre 1 e 12.")
        except ValueError:
            print("  ❌  Entrada inválida. Digite um número.")


def main() -> None:
    relatorios_acumulados = []

    while True:
        menu_principal()
        try:
            opcao = input("  Opção: ").strip()
        except (KeyboardInterrupt, EOFError):
            print("\n\n  Programa encerrado. Até logo! 👋")
            break

        if opcao == "0":
            print("\n  Programa encerrado. Até logo! 👋\n")
            break

        elif opcao == "1":
            mes, num_dias = escolher_mes()
            leituras = usar_dados_simulados(mes)
            relatorio = analisar_mes(mes, leituras)
            exibir_relatorio(relatorio)
            relatorios_acumulados.append(relatorio)

        elif opcao == "2":
            mes, num_dias = escolher_mes()
            leituras = coletar_dados_usuario(mes, num_dias)
            relatorio = analisar_mes(mes, leituras)
            exibir_relatorio(relatorio)
            relatorios_acumulados.append(relatorio)

        elif opcao == "3":
            print("\n  ⏳ Gerando relatório anual com dados simulados...")
            relatorios_anuais = []
            for mes in MESES:
                leituras = usar_dados_simulados(mes)
                rel = analisar_mes(mes, leituras)
                relatorios_anuais.append(rel)
                exibir_relatorio(rel)
            exibir_resumo_anual(relatorios_anuais)

        else:
            print("\n  ❌  Opção inválida. Tente novamente.")

        input("\n  [Pressione ENTER para continuar...]")


# ============================================================
# PONTO DE ENTRADA
# ============================================================

if __name__ == "__main__":
    main()
# Out:
# ============================================================
#    🌊  MONITORAMENTO DO NÍVEL DO RIO NEGRO  🌊
#    Projeto CETAM — Curso de IA | Módulo Python
# ============================================================
#
#   MENU PRINCIPAL
#   1 - Analisar um mês (dados simulados)
#   2 - Analisar um mês (inserir dados manualmente)
#   3 - Gerar relatório anual completo (simulado)
#   0 - Sair
#
#   Opção: 2
#
#   Escolha o mês:
#      1. Janeiro
#      2. Fevereiro
#      3. Março
#      4. Abril
#      5. Maio
#      6. Junho
#      7. Julho
#      8. Agosto
#      9. Setembro
#     10. Outubro
#     11. Novembro
#     12. Dezembro
#
#   Digite o número do mês: 6
#
#   Informe os níveis diários para Junho (30 dias):
#     Dia 01: 10
#     Dia 02:
#   ❌  Entrada inválida. Digite um número (ex: 25.40).
#     Dia 02: 10
#     Dia 03: 10
#     Dia 04: 10
#     Dia 05: 1
#     Dia 06: 0
#     Dia 07: 1
#     Dia 08: 1
#     Dia 09: 1
#     Dia 10: 1
#     Dia 11: 1
#     Dia 12: 1
#     Dia 13: 1
#     Dia 14: 1
#     Dia 15:
#   ❌  Entrada inválida. Digite um número (ex: 25.40).
#     Dia 15: 1
#     Dia 16: 1
#     Dia 17: 1
#     Dia 18:
#   ❌  Entrada inválida. Digite um número (ex: 25.40).
#     Dia 18: 1
#     Dia 19: 5
#     Dia 20: 5
#     Dia 21: 5
#     Dia 22:
#   ❌  Entrada inválida. Digite um número (ex: 25.40).
#     Dia 22: 2
#     Dia 23: 2
#     Dia 24: 2
#     Dia 25: 2
#     Dia 26: 2
#     Dia 27: 2
#     Dia 28: 2
#     Dia 29: 2
#     Dia 30: 2
#
# ============================================================
#   RELATÓRIO — JUNHO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  10.00 m  → 🏜️   SECA
#     Dia 02:  10.00 m  → 🏜️   SECA
#     Dia 03:  10.00 m  → 🏜️   SECA
#     Dia 04:  10.00 m  → 🏜️   SECA
#     Dia 05:   1.00 m  → 🏜️   SECA
#     Dia 06:   0.00 m  → 🏜️   SECA
#     Dia 07:   1.00 m  → 🏜️   SECA
#     Dia 08:   1.00 m  → 🏜️   SECA
#     Dia 09:   1.00 m  → 🏜️   SECA
#     Dia 10:   1.00 m  → 🏜️   SECA
#     Dia 11:   1.00 m  → 🏜️   SECA
#     Dia 12:   1.00 m  → 🏜️   SECA
#     Dia 13:   1.00 m  → 🏜️   SECA
#     Dia 14:   1.00 m  → 🏜️   SECA
#     Dia 15:   1.00 m  → 🏜️   SECA
#     Dia 16:   1.00 m  → 🏜️   SECA
#     Dia 17:   1.00 m  → 🏜️   SECA
#     Dia 18:   1.00 m  → 🏜️   SECA
#     Dia 19:   5.00 m  → 🏜️   SECA
#     Dia 20:   5.00 m  → 🏜️   SECA
#     Dia 21:   5.00 m  → 🏜️   SECA
#     Dia 22:   2.00 m  → 🏜️   SECA
#     Dia 23:   2.00 m  → 🏜️   SECA
#     Dia 24:   2.00 m  → 🏜️   SECA
#     Dia 25:   2.00 m  → 🏜️   SECA
#     Dia 26:   2.00 m  → 🏜️   SECA
#     Dia 27:   2.00 m  → 🏜️   SECA
#     Dia 28:   2.00 m  → 🏜️   SECA
#     Dia 29:   2.00 m  → 🏜️   SECA
#     Dia 30:   2.00 m  → 🏜️   SECA
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 2.87 m  (SECA)
#     • Dias em CHEIA     : 0
#     • Dias NORMAIS      : 0
#     • Dias em SECA      : 30
#     • Maior variação    : 9.00 m  (Dia 05)
#
#   🚨 ALERTAS HISTÓRICOS:
#     Dia 01: ⚠️  ALERTA CRÍTICO! Nível 10.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 02: ⚠️  ALERTA CRÍTICO! Nível 10.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 03: ⚠️  ALERTA CRÍTICO! Nível 10.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 04: ⚠️  ALERTA CRÍTICO! Nível 10.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 05: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 06: ⚠️  ALERTA CRÍTICO! Nível 0.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 07: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 08: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 09: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 10: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 11: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 12: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 13: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 14: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 15: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 16: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 17: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 18: ⚠️  ALERTA CRÍTICO! Nível 1.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 19: ⚠️  ALERTA CRÍTICO! Nível 5.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 20: ⚠️  ALERTA CRÍTICO! Nível 5.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 21: ⚠️  ALERTA CRÍTICO! Nível 5.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 22: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 23: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 24: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 25: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 26: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 27: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 28: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 29: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
#     Dia 30: ⚠️  ALERTA CRÍTICO! Nível 2.00m está ABAIXO do recorde histórico de SECA (13.64m)!
# ============================================================
#
#   [Pressione ENTER para continuar...]
#
# ============================================================
#    🌊  MONITORAMENTO DO NÍVEL DO RIO NEGRO  🌊
#    Projeto CETAM — Curso de IA | Módulo Python
# ============================================================
#
#   MENU PRINCIPAL
#   1 - Analisar um mês (dados simulados)
#   2 - Analisar um mês (inserir dados manualmente)
#   3 - Gerar relatório anual completo (simulado)
#   0 - Sair
#
#   Opção: 3
#
#   ⏳ Gerando relatório anual com dados simulados...
#
# ============================================================
#   RELATÓRIO — JANEIRO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  25.17 m  → ✅  NORMAL
#     Dia 02:  24.60 m  → ✅  NORMAL
#     Dia 03:  24.33 m  → ✅  NORMAL
#     Dia 04:  24.00 m  → ✅  NORMAL
#     Dia 05:  24.28 m  → ✅  NORMAL
#     Dia 06:  24.49 m  → ✅  NORMAL
#     Dia 07:  24.96 m  → ✅  NORMAL
#     Dia 08:  24.46 m  → ✅  NORMAL
#     Dia 09:  24.37 m  → ✅  NORMAL
#     Dia 10:  23.81 m  → ✅  NORMAL
#     Dia 11:  23.47 m  → ✅  NORMAL
#     Dia 12:  23.48 m  → ✅  NORMAL
#     Dia 13:  22.91 m  → ✅  NORMAL
#     Dia 14:  22.55 m  → ✅  NORMAL
#     Dia 15:  22.73 m  → ✅  NORMAL
#     Dia 16:  22.78 m  → ✅  NORMAL
#     Dia 17:  22.44 m  → ✅  NORMAL
#     Dia 18:  22.55 m  → ✅  NORMAL
#     Dia 19:  22.92 m  → ✅  NORMAL
#     Dia 20:  22.33 m  → ✅  NORMAL
#     Dia 21:  22.70 m  → ✅  NORMAL
#     Dia 22:  22.94 m  → ✅  NORMAL
#     Dia 23:  22.75 m  → ✅  NORMAL
#     Dia 24:  22.34 m  → ✅  NORMAL
#     Dia 25:  22.89 m  → ✅  NORMAL
#     Dia 26:  22.69 m  → ✅  NORMAL
#     Dia 27:  22.20 m  → ✅  NORMAL
#     Dia 28:  21.72 m  → ✅  NORMAL
#     Dia 29:  22.14 m  → ✅  NORMAL
#     Dia 30:  22.26 m  → ✅  NORMAL
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 23.24 m  (NORMAL)
#     • Dias em CHEIA     : 0
#     • Dias NORMAIS      : 30
#     • Dias em SECA      : 0
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RELATÓRIO — FEVEREIRO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  27.67 m  → ✅  NORMAL
#     Dia 02:  27.10 m  → ✅  NORMAL
#     Dia 03:  26.83 m  → ✅  NORMAL
#     Dia 04:  26.50 m  → ✅  NORMAL
#     Dia 05:  26.78 m  → ✅  NORMAL
#     Dia 06:  26.99 m  → ✅  NORMAL
#     Dia 07:  27.46 m  → ✅  NORMAL
#     Dia 08:  26.96 m  → ✅  NORMAL
#     Dia 09:  26.87 m  → ✅  NORMAL
#     Dia 10:  26.31 m  → ✅  NORMAL
#     Dia 11:  25.97 m  → ✅  NORMAL
#     Dia 12:  25.98 m  → ✅  NORMAL
#     Dia 13:  25.41 m  → ✅  NORMAL
#     Dia 14:  25.05 m  → ✅  NORMAL
#     Dia 15:  25.23 m  → ✅  NORMAL
#     Dia 16:  25.28 m  → ✅  NORMAL
#     Dia 17:  24.94 m  → ✅  NORMAL
#     Dia 18:  25.05 m  → ✅  NORMAL
#     Dia 17:  27.64 m  → ✅  NORMAL
#     Dia 18:  27.75 m  → ✅  NORMAL
#     Dia 19:  28.12 m  → ✅  NORMAL
#     Dia 20:  27.53 m  → ✅  NORMAL
#     Dia 21:  27.90 m  → ✅  NORMAL
#     Dia 22:  28.14 m  → ✅  NORMAL
#     Dia 23:  27.95 m  → ✅  NORMAL
#     Dia 24:  27.54 m  → ✅  NORMAL
#     Dia 25:  28.09 m  → ✅  NORMAL
#     Dia 26:  27.89 m  → ✅  NORMAL
#     Dia 27:  27.40 m  → ✅  NORMAL
#     Dia 28:  26.92 m  → ✅  NORMAL
#     Dia 29:  27.34 m  → ✅  NORMAL
#     Dia 30:  27.46 m  → ✅  NORMAL
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 28.44 m  (NORMAL)
#     • Dias em CHEIA     : 10
#     • Dias NORMAIS      : 20
#     • Dias em SECA      : 0
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   🚨 ALERTAS HISTÓRICOS:
#     Dia 01: ⚠️  ALERTA CRÍTICO! Nível 30.37m SUPERA o recorde histórico de CHEIA (29.97m - 2021/2022)!
#     Dia 07: ⚠️  ALERTA CRÍTICO! Nível 30.16m SUPERA o recorde histórico de CHEIA (29.97m - 2021/2022)!
# ============================================================
#
# ============================================================
#   RELATÓRIO — MAIO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  29.97 m  → 🌊  CHEIA
#     Dia 02:  29.40 m  → 🌊  CHEIA
#     Dia 03:  29.13 m  → 🌊  CHEIA
#     Dia 04:  28.80 m  → ✅  NORMAL
#     Dia 05:  29.08 m  → 🌊  CHEIA
#     Dia 06:  29.29 m  → 🌊  CHEIA
#     Dia 07:  29.76 m  → 🌊  CHEIA
#     Dia 08:  29.26 m  → 🌊  CHEIA
#     Dia 09:  29.17 m  → 🌊  CHEIA
#     Dia 10:  28.61 m  → ✅  NORMAL
#     Dia 11:  28.27 m  → ✅  NORMAL
#     Dia 12:  28.28 m  → ✅  NORMAL
#     Dia 13:  27.71 m  → ✅  NORMAL
#     Dia 14:  27.35 m  → ✅  NORMAL
#     Dia 15:  27.53 m  → ✅  NORMAL
#     Dia 16:  27.58 m  → ✅  NORMAL
#     Dia 17:  27.24 m  → ✅  NORMAL
#     Dia 18:  27.35 m  → ✅  NORMAL
#     Dia 19:  27.72 m  → ✅  NORMAL
#     Dia 20:  27.13 m  → ✅  NORMAL
#     Dia 21:  27.50 m  → ✅  NORMAL
#     Dia 22:  27.74 m  → ✅  NORMAL
#     Dia 23:  27.55 m  → ✅  NORMAL
#     Dia 24:  27.14 m  → ✅  NORMAL
#     Dia 25:  27.69 m  → ✅  NORMAL
#     Dia 26:  27.49 m  → ✅  NORMAL
#     Dia 27:  27.00 m  → ✅  NORMAL
#     Dia 28:  26.52 m  → ✅  NORMAL
#     Dia 29:  26.94 m  → ✅  NORMAL
#     Dia 30:  27.06 m  → ✅  NORMAL
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 28.04 m  (NORMAL)
#     • Dias em CHEIA     : 8
#     • Dias NORMAIS      : 22
#     • Dias em SECA      : 0
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RELATÓRIO — JUNHO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:

# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  22.17 m  → ✅  NORMAL
#     Dia 02:  21.60 m  → ✅  NORMAL
#     Dia 03:  21.33 m  → ✅  NORMAL
#     Dia 04:  21.00 m  → ✅  NORMAL
#     Dia 05:  21.28 m  → ✅  NORMAL
#     Dia 06:  21.49 m  → ✅  NORMAL
#     Dia 07:  21.96 m  → ✅  NORMAL
#     Dia 08:  21.46 m  → ✅  NORMAL
#     Dia 09:  21.37 m  → ✅  NORMAL
#     Dia 10:  20.81 m  → ✅  NORMAL
#     Dia 11:  20.47 m  → ✅  NORMAL
#     Dia 12:  20.48 m  → ✅  NORMAL
#     Dia 13:  19.91 m  → ✅  NORMAL
#     Dia 14:  19.55 m  → ✅  NORMAL
#     Dia 15:  19.73 m  → ✅  NORMAL
#     Dia 16:  19.78 m  → ✅  NORMAL
#     Dia 17:  19.44 m  → ✅  NORMAL
#     Dia 18:  19.55 m  → ✅  NORMAL
#     Dia 19:  19.92 m  → ✅  NORMAL
#     Dia 20:  19.33 m  → ✅  NORMAL
#     Dia 21:  19.70 m  → ✅  NORMAL
#     Dia 22:  19.94 m  → ✅  NORMAL
#     Dia 23:  19.75 m  → ✅  NORMAL
#     Dia 24:  19.34 m  → ✅  NORMAL
#     Dia 25:  19.89 m  → ✅  NORMAL
#     Dia 26:  19.69 m  → ✅  NORMAL
#     Dia 27:  19.20 m  → ✅  NORMAL
#     Dia 28:  18.72 m  → ✅  NORMAL
#     Dia 29:  19.14 m  → ✅  NORMAL
#     Dia 30:  19.26 m  → ✅  NORMAL
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 20.24 m  (NORMAL)
#     • Dias em CHEIA     : 0
#     • Dias NORMAIS      : 30
#     • Dias em SECA      : 0
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RELATÓRIO — SETEMBRO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  18.67 m  → ✅  NORMAL
#     Dia 02:  18.10 m  → ✅  NORMAL
#     Dia 03:  17.83 m  → 🏜️   SECA
#     Dia 04:  17.50 m  → 🏜️   SECA
#     Dia 05:  17.78 m  → 🏜️   SECA
#     Dia 06:  17.99 m  → 🏜️   SECA
#     Dia 07:  18.46 m  → ✅  NORMAL
#     Dia 08:  17.96 m  → 🏜️   SECA
#     Dia 09:  17.87 m  → 🏜️   SECA
#     Dia 10:  17.31 m  → 🏜️   SECA
#     Dia 11:  16.97 m  → 🏜️   SECA
#     Dia 12:  16.98 m  → 🏜️   SECA
#     Dia 13:  16.41 m  → 🏜️   SECA
#     Dia 14:  16.05 m  → 🏜️   SECA
#     Dia 15:  16.23 m  → 🏜️   SECA
#     Dia 16:  16.28 m  → 🏜️   SECA
#     Dia 17:  15.94 m  → 🏜️   SECA
#     Dia 18:  16.05 m  → 🏜️   SECA
#     Dia 19:  16.42 m  → 🏜️   SECA
#     Dia 20:  15.83 m  → 🏜️   SECA
#     Dia 21:  16.20 m  → 🏜️   SECA
#     Dia 22:  16.44 m  → 🏜️   SECA
#     Dia 23:  16.25 m  → 🏜️   SECA
#     Dia 24:  15.84 m  → 🏜️   SECA
#     Dia 25:  16.39 m  → 🏜️   SECA
#     Dia 26:  16.19 m  → 🏜️   SECA
#     Dia 27:  15.70 m  → 🏜️   SECA
#     Dia 28:  15.22 m  → 🏜️   SECA
#     Dia 29:  15.64 m  → 🏜️   SECA
#     Dia 30:  15.76 m  → 🏜️   SECA
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 16.74 m  (SECA)
#     • Dias em CHEIA     : 0
#     • Dias NORMAIS      : 3
#     • Dias em SECA      : 27
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RELATÓRIO — OUTUBRO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RELATÓRIO — DEZEMBRO
# ============================================================
#
#   📅 LEITURAS DIÁRIAS:
#     Dia 01:  22.17 m  → ✅  NORMAL
#     Dia 02:  21.60 m  → ✅  NORMAL
#     Dia 03:  21.33 m  → ✅  NORMAL
#     Dia 04:  21.00 m  → ✅  NORMAL
#     Dia 05:  21.28 m  → ✅  NORMAL
#     Dia 06:  21.49 m  → ✅  NORMAL
#     Dia 07:  21.96 m  → ✅  NORMAL
#     Dia 08:  21.46 m  → ✅  NORMAL
#     Dia 09:  21.37 m  → ✅  NORMAL
#     Dia 10:  20.81 m  → ✅  NORMAL
#     Dia 11:  20.47 m  → ✅  NORMAL
#     Dia 12:  20.48 m  → ✅  NORMAL
#     Dia 13:  19.91 m  → ✅  NORMAL
#     Dia 14:  19.55 m  → ✅  NORMAL
#     Dia 15:  19.73 m  → ✅  NORMAL
#     Dia 16:  19.78 m  → ✅  NORMAL
#     Dia 17:  19.44 m  → ✅  NORMAL
#     Dia 18:  19.55 m  → ✅  NORMAL
#     Dia 19:  19.92 m  → ✅  NORMAL
#     Dia 20:  19.33 m  → ✅  NORMAL
#     Dia 21:  19.70 m  → ✅  NORMAL
#     Dia 22:  19.94 m  → ✅  NORMAL
#     Dia 23:  19.75 m  → ✅  NORMAL
#     Dia 24:  19.34 m  → ✅  NORMAL
#     Dia 25:  19.89 m  → ✅  NORMAL
#     Dia 26:  19.69 m  → ✅  NORMAL
#     Dia 27:  19.20 m  → ✅  NORMAL
#     Dia 28:  18.72 m  → ✅  NORMAL
#     Dia 29:  19.14 m  → ✅  NORMAL
#     Dia 30:  19.26 m  → ✅  NORMAL
#
#   📊 RESUMO DO MÊS:
#     • Média mensal      : 20.24 m  (NORMAL)
#     • Dias em CHEIA     : 0
#     • Dias NORMAIS      : 30
#     • Dias em SECA      : 0
#     • Maior variação    : 0.59 m  (Dia 20)
#
#   ✅ Nenhum nível ultrapassou os limites históricos.
# ============================================================
#
# ============================================================
#   RESUMO ANUAL — RIO NEGRO
# ============================================================
#   Mês           Média (m) Classificação Alertas
#   ----------------------------------------------
#   Janeiro           23.24 ✅ NORMAL         0
#   Fevereiro         25.74 ✅ NORMAL         0
#   Março             27.74 ✅ NORMAL         0
#   Abril             28.44 ✅ NORMAL         2
#   Maio              28.04 ✅ NORMAL         0
#   Junho             26.24 ✅ NORMAL         0
#   Julho             23.74 ✅ NORMAL         0
#   Agosto            20.24 ✅ NORMAL         0
#   Setembro          16.74 🏜️  SECA           0
#   Outubro           15.24 🏜️  SECA           0
#   Novembro          16.74 🏜️  SECA           0
#   Dezembro          20.24 ✅ NORMAL         0
# ============================================================
#
#   [Pressione ENTER para continuar...]
#
# ============================================================
#    🌊  MONITORAMENTO DO NÍVEL DO RIO NEGRO  🌊
#    Projeto CETAM — Curso de IA | Módulo Python
# ============================================================
#
#   MENU PRINCIPAL
#   1 - Analisar um mês (dados simulados)
#   2 - Analisar um mês (inserir dados manualmente)
#   3 - Gerar relatório anual completo (simulado)
#   0 - Sair
#
#   Opção: 0
#
#   Programa encerrado. Até logo! 👋
